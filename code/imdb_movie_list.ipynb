# %%
import pandas as pd
df = pd.read_csv("../data/raw/imdb_scraped.csv")
df
# Out:
#                     Title Release Year Certificate  \
# 0           Incredibles 2       (2018)          PG
# 1            Finding Dory       (2016)          PG
# 2               Frozen II       (2019)          PG
# 3                 Shrek 2       (2004)          PG
# 4             Toy Story 4       (2019)           G
# ...                   ...          ...         ...
# 4345           Tangerines       (2013)   Not Rated
# 4346            Tigerland       (2000)           R
# 4347         The Warlords       (2007)           R
# 4348            Centurion       (2010)           R
# 4349  Beasts of No Nation       (2015)       TV-MA
#
#                                           Genres  IMDB Rating    Votes  \
# 0     \nAnimation, Action, Adventure                      7.6  280,820
# 1     \nAnimation, Adventure, Comedy                      7.3  264,109
# 2     \nAnimation, Adventure, Comedy                      6.8  161,851
# ...

# %%
top_1000_gross = (df
      .assign(gross_clean = lambda df_: df_["Gross Revenue"]
              .str.replace("$","")
              .str.replace("M","")
              .astype(float))
      .sort_values("gross_clean", ascending=False)
     .drop_duplicates(subset=["Title", "Release Year"])
     .reset_index(drop=True)[:1000])
top_1000_gross
# Need to figure out this error and see if there is a simple fix
# need to clean release year for matching for the omdb data
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                           Title Release Year Certificate  \
# 0    Star Wars: Episode VII - The Force Awakens       (2015)       PG-13
# 1                             Avengers: Endgame       (2019)       PG-13
# 2                                        Avatar       (2009)       PG-13
# 3                                 Black Panther       (2018)       PG-13
# 4                        Avengers: Infinity War       (2018)       PG-13
# ..                                          ...          ...         ...
# 995                 Father of the Bride Part II       (1995)          PG
# ...
