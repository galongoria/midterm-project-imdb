# %%
import pandas as pd
df = pd.read_csv("../data/raw/tester_imdb_scrape.csv")
df
# Out:
#                     Title Release Year Certificate  \
# 0           Incredibles 2       (2018)          PG
# 1            Finding Dory       (2016)          PG
# 2               Frozen II       (2019)          PG
# 3                 Shrek 2       (2004)          PG
# 4             Toy Story 4       (2019)           G
# ...                   ...          ...         ...
# 4345           Tangerines       (2013)   Not Rated
# 4346            Tigerland       (2000)           R
# 4347         The Warlords       (2007)           R
# 4348            Centurion       (2010)           R
# 4349  Beasts of No Nation       (2015)       TV-MA
#
#                                           Genres  IMDB Rating    Votes  \
# 0     \nAnimation, Action, Adventure                      7.6  280,789
# 1     \nAnimation, Adventure, Comedy                      7.3  264,085
# 2     \nAnimation, Adventure, Comedy                      6.8  161,827
# ...

# %%
unique_titles = (df[["Title", "Release Year"]]
                 .drop_duplicates()
                 .assign(year=lambda df_: df_["Release Year"]
                         .str.replace("(","")
                         .str.replace(")",""))
                 .drop(columns="Release Year")
                 .to_csv("../data/raw/movies_list.csv",index=False))
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """
